# %%
import import_ipynb
from utils import *
fig

# %%
df_information, outcomes = ZDGo()
# Out:
# Enter your player: Human
# Enter chi (chi is the extortion factor and is a number no less than 1): 2
# Enter number of rounds n (n is a positive integer): 20
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>your strategy</th>
#       <th>extortion factor</th>
#       <th>number of rounds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th></th>
#       <td>Human</td>
#       <td>2.0</td>
#       <td>20</td>
#     </tr>
#   </tbody>
# </table>
# Round 1| enter your action (C or D): D
# round 1| outcome: (D, C)
# Round 2| enter your action (C or D): C
# round 2| outcome: (C, C)
# Round 3| enter your action (C or D): D
# round 3| outcome: (D, C)
# Round 4| enter your action (C or D): C
# round 4| outcome: (C, D)
# Round 5| enter your action (C or D): C
# round 5| outcome: (C, D)
# Round 6| enter your action (C or D): C
# round 6| outcome: (C, C)
# Round 7| enter your action (C or D): D
# ...

# %%
pie = figure_pie(df_information)
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="cc59af59ed5e4c8a9aa5674fe0f6bd9c" style="width:600px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_cc59af59ed5e4c8a9aa5674fe0f6bd9c = echarts.init(
#                     document.getElementById('cc59af59ed5e4c8a9aa5674fe0f6bd9c'), 'white', {renderer: 'canvas'});
#                 var option_cc59af59ed5e4c8a9aa5674fe0f6bd9c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
df_information, outcomes = ZDGo(printing = False)
# Out:
# Enter your player: Tit For Tat
# Enter chi (chi is the extortion factor and is a number no less than 1): 4
# Enter number of rounds n (n is a positive integer): 1000
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>your strategy</th>
#       <th>extortion factor</th>
#       <th>number of rounds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th></th>
#       <td>Tit For Tat</td>
#       <td>4.0</td>
#       <td>1000</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>your strategy</th>
#       <th>extortion factor</th>
#       <th>number of rounds</th>
#       <th>player's score</th>
#       <th>ZD's score</th>
#       <th>(C, C) pair</th>
#       <th>(C, D) pair</th>
#       <th>(D, C) pair</th>
#       <th>(D, D) pair</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th></th>
# ...

# %%
df_information, outcomes = ZDGo(printing = False)
# Out:
# Enter your player: win stay lose shift
# Do you mean Win-Stay Lose-Shift? If yes, enter Win-Stay Lose-Shift, otherwise, choose another player: Win-Stay Lose-Shift
# Enter chi (chi is the extortion factor and is a number no less than 1): 3
# Enter number of rounds n (n is a positive integer): 1000
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>your strategy</th>
#       <th>extortion factor</th>
#       <th>number of rounds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th></th>
#       <td>Win-Stay Lose-Shift</td>
#       <td>3.0</td>
#       <td>1000</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>your strategy</th>
#       <th>extortion factor</th>
#       <th>number of rounds</th>
#       <th>player's score</th>
#       <th>ZD's score</th>
#       <th>(C, C) pair</th>
# ...

# %%
pie = figure_pie(df_information)
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="cf0c0c80d81e468d9702c971e93b6c17" style="width:600px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_cf0c0c80d81e468d9702c971e93b6c17 = echarts.init(
#                     document.getElementById('cf0c0c80d81e468d9702c971e93b6c17'), 'white', {renderer: 'canvas'});
#                 var option_cf0c0c80d81e468d9702c971e93b6c17 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
